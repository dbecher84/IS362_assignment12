# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
from pandas.io.json import json_normalize

# %% [markdown]
# Times api key the url to access and a item with the url and api combined for accessing the site

# %%
#New York Times API Key
api_key = '&api-key=2d244d85fa314801865d473a41a6c039'

url = 'http://api.nytimes.com/svc/movies/v2/reviews/search.json?critics-pick=Y?order=by-date&offset=40'

site_w_api = url+api_key

# %% [markdown]
# access the site and place the data into a pandas data frame

# %%
response = urlopen(site_w_api)
site_data = response.read()

# %%
reviews = json.loads(site_data)
reviews_df = json_normalize(reviews['results'])

# %%
reviews_df.sort_values(by=['display_title'])
# Out:
#                  byline  critics_pick         date_updated  \
# 2           GLENN KENNY             1  2018-11-02 16:44:01
# 6            TEO BUGBEE             0  2018-11-02 16:44:01
# 9        KEN JAWOROWSKI             0  2018-10-25 11:04:10
# 18       BEN KENIGSBERG             0  2018-10-26 16:44:01
# 7        BEN KENIGSBERG             0  2018-11-10 17:44:15
# 10       BEN KENIGSBERG             0  2018-11-10 17:44:13
# 12       BEN KENIGSBERG             1  2018-11-07 17:44:01
# 8   JEANNETTE CATSOULIS             0  2018-11-02 16:44:01
# 14    HELEN T. VERONGOS             1  2018-10-26 16:44:01
# 15       KEN JAWOROWSKI             1  2018-10-26 16:44:01
# 0   JEANNETTE CATSOULIS             1  2018-11-02 16:44:01
# 11       MANOHLA DARGIS             0  2018-11-10 17:44:13
# 3            TEO BUGBEE             0  2018-10-25 16:38:03
# 16  JEANNETTE CATSOULIS             1  2018-11-10 17:44:10
# 17          BILGE EBIRI             0  2018-11-02 16:44:01
# ...
